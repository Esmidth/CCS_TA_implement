# %%
# %matplotlib inline
import utils
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
res = 30
lat = (40.659645,40.779103)
log = (-73.989985,-73.730483)

# %%
df = utils.get_data('rat')
df['New_Date'] = pd.to_datetime(df['Created Date'])
# print(df)
date_range = np.linspace(2010,2020,11,dtype=int)
# date_count = np.zeros(10,dtype=int)
def generate_date_dataframe(date_range,df):
    """date_range: (from,to)"""
    return df[(df['New_Date'] > str(date_range[0])) & (df['New_Date'] < str(date_range[1]))]

# %%
date_df_2010_2014 = generate_date_dataframe((2010,2014),df)
print(len(date_df_2010_2014))
pic = draw_rat_heatmap(lat,log,date_df_2010_2014,30)

print(len(pic_list))
# Out:
# 42370
# 30

# %%
def draw_rat_heatmap(lat,log,df,res):
    lat_range = np.linspace(lat[0],lat[1],res+1)
    log_range = np.linspace(log[0],log[1],res+1)
    pic = np.zeros((res,res))
    for i in range(res):
        # print(i,lat_range[i],lat_range[i+1])
        for j in range(res):
            sub_df = df[(df['Latitude'] > lat_range[i]) & (df['Latitude'] < lat_range[i+1]) & (df['Longitude'] > log_range[j]) & (df['Longitude'] < log_range[j+1])]
            pic[i][j] = len(sub_df)
    return pic

# %%
def show_year_heatmap():
    date_df_list = []
    for i in range(10):
        sub_df = generate_date_dataframe((2010+i,2011+i),df)
        date_df_list.append(sub_df)
    pic_list = []
    for date_df in date_df_list:
        pic = draw_rat_heatmap(lat,log,date_df,20)
        pic_list.append(pic)
    plt.figure(figsize=(10,10))
    for i,pic in enumerate(pic_list):    
        plt.subplot(2,5,i+1)
        plt.imshow(pic)
        plt.title(str(2010+i)+'-'+str(2011+i))
    plt.tight_layout()
    plt.show()
def draw_pics(pic_list,arrange=(1,len(pic_list)),name=2010):
    plt.figure(figsize=(10,10))
    x = arrange[0]
    y = arrange[1]
    for i,pic in enumerate(pic_list):
        plt.subplot(x,y,i+1)
        plt.imshow(pic)
        plt.title(str(name+i))
    plt.tight_layout()
    plt.show()

def get_year_heatmap(date_range,df,res):
    """date_range: (start_year,end_year)"""
    date_df_list = []
    date_range_verbose = np.linspace(date_range[0],date_range[1],date_range[1]-date_range[0]+1,dtype=int)
    # print(date_range_verbose)
    for i in range(date_range[1]-date_range[0]):
        # print(date_range_verbose[i],date_range_verbose[i+1])
        sub_df = generate_date_dataframe((date_range_verbose[i],date_range_verbose[i+1]),df)
        date_df_list.append(sub_df)
    pic_list = []
    for date_df in date_df_list:
        pic = draw_rat_heatmap(lat,log,date_df,res)
        pic_list.append(pic)
    return pic_list

# show_year_heatmap()
pic_list = get_year_heatmap((2011,2015),df,20)
draw_pics(pic_list,(2,2),2011)
# Out:
# 4

# %%
# sub_df = df[(df['Latitude'] > lat[0]) & (df['Latitude']<lat[1]) & (df['Longitude'] > log[0]) & (df['Longitude'] < log[1])]
#date_df = 
#print(df['Created Date'])
# date_df=df[df['Created Date'] > '02/24/2015 10:05:58']
# df['New_Date'] = pd.to_datetime(df['Created Date'])

# print(df.dtypes)

# print(date_range)
# for i in range(10):
    # date_df = generate_date_dataframe((date_range[i],date_range[i+1]),df)
    # date_count[i] = len(date_df)
    # print(i,date_range[i],date_range[i+1],len(date_df))
date_df = generate_date_dataframe((2015,2016),df)
print(len(date_df))
    
# date_df = df[df['New_Date'] > '2015']
# print(date_count)
# print(df['New_Date'].describe())
# print(len(date_df))
# print((date_df['Created Date'].values[0]))

# print(sub_df['Location'])
